# %% [markdown]
# # Set up

# %%
project_folder = "/content/drive/MyDrive/weather_predictor"

from google.colab import drive
drive.mount('/content/drive')

# %cd "{project_folder}"
# !git pull
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/weather_predictor
# Already up to date.

# %% [markdown]
# # Cài đặt môi trường

# %%
# !git pull
# !pip install -r requirements.txt
# Out:
# Already up to date.
# Obtaining file:///content/drive/MyDrive/weather_predictor (from -r requirements.txt (line 16))
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: classifier
#     Found existing installation: classifier 0.0.0
#     Uninstalling classifier-0.0.0:
#       Successfully uninstalled classifier-0.0.0
#   Running setup.py develop for classifier
# ...

# %%
# !pip show zzzz_mylib_23_4
# Out:
# Name: zzzz_mylib_23_4
# Version: 0.24
# Summary:
# Home-page:
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires:
# Required-by:

# %% [markdown]
# # Thư viện

# %%
from Mylib import myfuncs

# %% [markdown]
# # Chạy stage

# %%
# !git pull
# !python run.py data_transformation n
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 279 bytes | 5.00 KiB/s, done.
# From https://github.com/zalexdevon/weather_predictor
#    33ca0da..f40af60  main       -> origin/main
# Updating 33ca0da..f40af60
# Fast-forward
#  dvc_p.yaml | 4 ----
#  1 file changed, 4 deletions(-)
# 2025-04-26 02:42:57.149197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745635377.199837   58254 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# # Biểu đồ các lần train model

# %%
fig = myfuncs.load_python_object("artifacts/model_trainer/monitor_plot_fig.pkl")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
